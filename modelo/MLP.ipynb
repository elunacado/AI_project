# %%
import pandas as pd
import numpy as np
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, f1_score
import seaborn as sns
import matplotlib.pyplot as plt
from tensorflow import keras
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1776636730.914276   32840 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1776636730.914642   32840 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1776636730.956329   32840 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1776636732.119417   32840 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1776636732.119740   32840 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
# Se lee el dataset preprocesado
df = pd.read_csv('../preprocesamiento/preprocesamiento_trainning.data', header=None)
x = df.iloc[:, :-1]
y = df.iloc[:, -1]
clases = sorted(y.unique().astype(int).tolist())
clase_nombres = {
    0: "High Card", 1: "One Pair", 2: "Two Pairs", 3: "Three of a Kind",
    4: "Straight",  5: "Flush",   6: "Full House", 7: "Four of a Kind",
    8: "Straight Flush", 9: "Royal Flush"
}
nombres_ordenados = [clase_nombres[c] for c in clases]


# Todas las columnas excepto la última
# Última columna
x = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

# Número de clases distintas
# Número de características (features) por muestra
n_clases = len(np.unique(y))
n_features = x.shape[1]


modelo_tf = keras.Sequential([    
    # Capa de entrada: recibe vectores de tamaño n_features
    keras.layers.Input(shape=(n_features,)),
    # Primera capa oculta con 64 neuronas y activación ReLU
    keras.layers.Dense(64, activation='relu'),
    # Segunda capa oculta con 32 neuronas y activación ReLU
    keras.layers.Dense(32, activation='relu'),
    # Capa de salida:
    # n_clases neuronas (una por clase)
    # softmax convierte las salidas en probabilidades
    keras.layers.Dense(n_clases, activation='softmax')
])

# Compilación del modelo:
modelo_tf.compile(
    optimizer='adam',  # algoritmo de optimización
    loss='sparse_categorical_crossentropy',  
    # Se usa porque y NO está en one-hot, sino como etiquetas enteras
    metrics=['accuracy']  # métrica de evaluación
)

# Muestra un resumen del modelo (capas, parámetros, etc.)
modelo_tf.summary()


history = modelo_tf.fit(
    x, y,
    epochs=10,          # número de iteraciones completas sobre el dataset
    batch_size=32,      # tamaño de lote
    validation_split=0.2,  # 20% de los datos se usan para validación
    verbose=1           # muestra progreso en consola
)

# Predicciones del modelo (probabilidades por clase)
y_pred_tf = np.argmax(modelo_tf.predict(x), axis=1)

# Se usa argmax para convertir probabilidades en la clase con mayor valor


# Accuracy: proporción de aciertos
print(f"Accuracy : {accuracy_score(y, y_pred_tf):.4f}")
# Recall macro: promedio del recall por clase (útil en datasets desbalanceados)
print(f"Recall   : {recall_score(y, y_pred_tf, average='macro', zero_division=0):.4f}")
# F1-score macro: balance entre precisión y recall por clase
print(f"F1       : {f1_score(y, y_pred_tf, average='macro', zero_division=0):.4f}")


# Calcula la matriz de confusión
cm_tf = confusion_matrix(y, y_pred_tf)

# Se grafica con seaborn
plt.figure(figsize=(10, 7))
sns.heatmap(
    cm_tf, 
    annot=True,        # muestra números dentro de cada celda
    fmt='d',           # formato entero
    cmap='Blues',      # esquema de colores
    xticklabels=nombres_ordenados,
    yticklabels=nombres_ordenados,
)

# Etiquetas del gráfico
plt.title("Matriz de Confusión — MLP TensorFlow")
plt.xlabel("Predicho")
plt.ylabel("Real")

# Ajustes visuales
plt.tick_params(axis='x', rotation=45)
plt.tick_params(axis='y', rotation=0)
plt.tight_layout()

# Mostrar gráfico
plt.show()
# Out:
# E0000 00:00:1776636733.005179   32840 cuda_executor.cc:1737] INTERNAL: CUDA Runtime error: Failed call to cudaGetRuntimeVersion: Error loading CUDA libraries. GPU will not be used.: Error loading CUDA libraries. GPU will not be used.
# W0000 00:00:1776636733.005498   32892 cuda_executor.cc:1755] Failed to determine cuDNN version (Note that this is expected if the application doesn't link the cuDNN plugin): INTERNAL: cuDNN error: CUDNN_STATUS_INTERNAL_ERROR
# W0000 00:00:1776636733.023531   32840 gpu_device.cc:2365] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │         1,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │           330 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,074 (15.91 KB)
#  Trainable params: 4,074 (15.91 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 8s 963us/step - accuracy: 0.4708 - loss: 1.0325 - val_accuracy: 0.0000e+00 - val_loss: 9.2313
# Epoch 2/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 7s 932us/step - accuracy: 0.4951 - loss: 1.0068 - val_accuracy: 0.0000e+00 - val_loss: 10.8849
# Epoch 3/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 7s 925us/step - accuracy: 0.5006 - loss: 1.0017 - val_accuracy: 0.0000e+00 - val_loss: 13.0049
# Epoch 4/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 7s 955us/step - accuracy: 0.5065 - loss: 0.9951 - val_accuracy: 0.0000e+00 - val_loss: 16.5672
# Epoch 5/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 7s 965us/step - accuracy: 0.5178 - loss: 0.9812 - val_accuracy: 0.0000e+00 - val_loss: 16.5430
# Epoch 6/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 7s 984us/step - accuracy: 0.5265 - loss: 0.9669 - val_accuracy: 0.0000e+00 - val_loss: 16.8607
# Epoch 7/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 7s 997us/step - accuracy: 0.5350 - loss: 0.9536 - val_accuracy: 0.0000e+00 - val_loss: 17.7762
# Epoch 8/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - accuracy: 0.5437 - loss: 0.9380 - val_accuracy: 1.2019e-04 - val_loss: 18.2153
# Epoch 9/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - accuracy: 0.5543 - loss: 0.9204 - val_accuracy: 2.5755e-04 - val_loss: 17.7389
# Epoch 10/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - accuracy: 0.5640 - loss: 0.9041 - val_accuracy: 0.0023 - val_loss: 18.0135
# Epoch 11/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.5749 - loss: 0.8866 - val_accuracy: 0.0013 - val_loss: 17.6405
# Epoch 12/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.5869 - loss: 0.8677 - val_accuracy: 8.7569e-04 - val_loss: 18.3783
# Epoch 13/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.5978 - loss: 0.8507 - val_accuracy: 0.0013 - val_loss: 19.6008
# Epoch 14/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.6083 - loss: 0.8349 - val_accuracy: 0.0014 - val_loss: 19.8829
# Epoch 15/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.6174 - loss: 0.8187 - val_accuracy: 6.3530e-04 - val_loss: 20.4784
# Epoch 16/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.6267 - loss: 0.8024 - val_accuracy: 0.0013 - val_loss: 20.9558
# Epoch 17/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.6364 - loss: 0.7849 - val_accuracy: 0.0023 - val_loss: 22.1163
# Epoch 18/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.6487 - loss: 0.7667 - val_accuracy: 0.0070 - val_loss: 23.0589
# Epoch 19/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.6576 - loss: 0.7508 - val_accuracy: 0.0070 - val_loss: 24.0996
# Epoch 20/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.6645 - loss: 0.7371 - val_accuracy: 0.0104 - val_loss: 25.2584
# Epoch 21/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.6711 - loss: 0.7254 - val_accuracy: 0.0045 - val_loss: 25.8805
# Epoch 22/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.6765 - loss: 0.7140 - val_accuracy: 0.0102 - val_loss: 27.1263
# Epoch 23/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.6829 - loss: 0.7019 - val_accuracy: 0.0128 - val_loss: 27.6704
# Epoch 24/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.6914 - loss: 0.6883 - val_accuracy: 0.0074 - val_loss: 28.3450
# Epoch 25/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.6989 - loss: 0.6752 - val_accuracy: 0.0111 - val_loss: 30.0396
# Epoch 26/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - accuracy: 0.7123 - loss: 0.6544 - val_accuracy: 0.0087 - val_loss: 31.8689
# Epoch 27/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - accuracy: 0.7217 - loss: 0.6356 - val_accuracy: 0.0134 - val_loss: 33.8237
# Epoch 28/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - accuracy: 0.7274 - loss: 0.6218 - val_accuracy: 0.0186 - val_loss: 34.8673
# Epoch 29/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - accuracy: 0.7322 - loss: 0.6102 - val_accuracy: 0.0070 - val_loss: 36.0294
# Epoch 30/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step - accuracy: 0.7372 - loss: 0.5996 - val_accuracy: 0.0177 - val_loss: 36.5268
# Epoch 31/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step - accuracy: 0.7409 - loss: 0.5908 - val_accuracy: 0.0158 - val_loss: 37.2841
# Epoch 32/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.7468 - loss: 0.5798 - val_accuracy: 0.0096 - val_loss: 38.1203
# Epoch 33/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.7509 - loss: 0.5701 - val_accuracy: 0.0314 - val_loss: 38.3298
# Epoch 34/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.7567 - loss: 0.5596 - val_accuracy: 0.0151 - val_loss: 39.0746
# Epoch 35/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.7620 - loss: 0.5478 - val_accuracy: 0.0119 - val_loss: 39.6752
# Epoch 36/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - accuracy: 0.7666 - loss: 0.5369 - val_accuracy: 0.0234 - val_loss: 40.3926
# Epoch 37/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - accuracy: 0.7706 - loss: 0.5266 - val_accuracy: 0.0189 - val_loss: 40.4736
# Epoch 38/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step - accuracy: 0.7758 - loss: 0.5174 - val_accuracy: 0.0292 - val_loss: 41.2634
# Epoch 39/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.7799 - loss: 0.5085 - val_accuracy: 0.0304 - val_loss: 41.2817
# Epoch 40/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.7821 - loss: 0.5015 - val_accuracy: 0.0191 - val_loss: 41.5189
# Epoch 41/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step - accuracy: 0.7866 - loss: 0.4928 - val_accuracy: 0.0402 - val_loss: 41.3078
# Epoch 42/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step - accuracy: 0.7906 - loss: 0.4851 - val_accuracy: 0.0245 - val_loss: 41.7899
# Epoch 43/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - accuracy: 0.7949 - loss: 0.4752 - val_accuracy: 0.0286 - val_loss: 42.2332
# Epoch 44/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.8017 - loss: 0.4613 - val_accuracy: 0.0084 - val_loss: 43.4530
# Epoch 45/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - accuracy: 0.8081 - loss: 0.4480 - val_accuracy: 0.0328 - val_loss: 43.7266
# Epoch 46/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - accuracy: 0.8134 - loss: 0.4378 - val_accuracy: 0.0336 - val_loss: 44.9991
# Epoch 47/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step - accuracy: 0.8169 - loss: 0.4296 - val_accuracy: 0.0280 - val_loss: 45.1085
# Epoch 48/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.8231 - loss: 0.4178 - val_accuracy: 0.0395 - val_loss: 46.6918
# Epoch 49/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.8291 - loss: 0.4048 - val_accuracy: 0.0237 - val_loss: 47.0406
# Epoch 50/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.8361 - loss: 0.3893 - val_accuracy: 0.0353 - val_loss: 46.8958
# 9100/9100 ━━━━━━━━━━━━━━━━━━━━ 5s 556us/step
# Accuracy : 0.6767
# Recall   : 0.2482
# F1       : 0.2218
