# %%
import pandas as pd
import numpy as np
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, f1_score
import seaborn as sns
import matplotlib.pyplot as plt
from tensorflow import keras

# %%
# Se lee el dataset preprocesado
df = pd.read_csv('../preprocesamiento/preprocesamiento_trainning.data', header=None)
x = df.iloc[:, :-1]
y = df.iloc[:, -1]
clases = sorted(y.unique().astype(int).tolist())
clase_nombres = {
    0: "High Card", 1: "One Pair", 2: "Two Pairs", 3: "Three of a Kind",
    4: "Straight",  5: "Flush",   6: "Full House", 7: "Four of a Kind",
    8: "Straight Flush", 9: "Royal Flush"
}
nombres_ordenados = [clase_nombres[c] for c in clases]


x = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

# Número de clases distintas
# Número de características (features) por muestra
n_clases = len(np.unique(y))
n_features = x.shape[1]


modelo_tf = keras.Sequential([    
    # Capa de entrada: recibe vectores de tamaño n_features
    keras.layers.Input(shape=(n_features,)),
    # Primera capa oculta con 64 neuronas y activación ReLU
    keras.layers.Dense(64, activation='relu'),
    # Segunda capa oculta con 32 neuronas y activación ReLU
    keras.layers.Dense(32, activation='relu'),
    # Capa de salida:
    # n_clases neuronas (una por clase)
    # softmax convierte las salidas en probabilidades
    keras.layers.Dense(n_clases, activation='softmax')
])

# Compilación del modelo:
modelo_tf.compile(
    optimizer='adam',  # algoritmo de optimización
    loss='sparse_categorical_crossentropy',  
    metrics=['accuracy']  # métrica de evaluación
)

# Muestra un resumen del modelo (capas, parámetros, etc.)
modelo_tf.summary()


history = modelo_tf.fit(
    x, y,
    epochs=50,          # número de iteraciones completas sobre el dataset
    batch_size=32,      # tamaño de lote
    validation_split=0.2,  # 20% de los datos se usan para validación
    verbose=1           # muestra progreso en consola
)

# Predicciones del modelo (probabilidades por clase)
y_pred_tf = np.argmax(modelo_tf.predict(x), axis=1)

# Se usa argmax para convertir probabilidades en la clase con mayor valor


# Accuracy: proporción de aciertos
print(f"Accuracy : {accuracy_score(y, y_pred_tf):.4f}")
# Recall macro: promedio del recall por clase (útil en datasets desbalanceados)
print(f"Recall   : {recall_score(y, y_pred_tf, average='macro', zero_division=0):.4f}")
# F1-score macro: balance entre precisión y recall por clase
print(f"F1       : {f1_score(y, y_pred_tf, average='macro', zero_division=0):.4f}")


# Calcula la matriz de confusión
cm_tf = confusion_matrix(y, y_pred_tf)

# Se grafica con seaborn
plt.figure(figsize=(10, 7))
sns.heatmap(
    cm_tf, 
    annot=True,        # muestra números dentro de cada celda
    fmt='d',           # formato entero
    cmap='Blues',      # esquema de colores
    xticklabels=nombres_ordenados,
    yticklabels=nombres_ordenados,
)

# Etiquetas del gráfico
plt.title("Matriz de Confusión — MLP TensorFlow")
plt.xlabel("Predicho")
plt.ylabel("Real")

# Ajustes visuales
plt.tick_params(axis='x', rotation=45)
plt.tick_params(axis='y', rotation=0)
plt.tight_layout()

# Mostrar gráfico
plt.show()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 64)             │         1,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 10)             │           330 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,074 (15.91 KB)
#  Trainable params: 4,074 (15.91 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 7s 961us/step - accuracy: 0.4690 - loss: 1.0348 - val_accuracy: 0.0000e+00 - val_loss: 9.1891
# Epoch 2/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 6s 865us/step - accuracy: 0.4954 - loss: 1.0073 - val_accuracy: 0.0000e+00 - val_loss: 11.4547
# Epoch 3/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 6s 888us/step - accuracy: 0.5001 - loss: 1.0029 - val_accuracy: 0.0000e+00 - val_loss: 15.3068
# Epoch 4/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 7s 932us/step - accuracy: 0.5051 - loss: 0.9988 - val_accuracy: 0.0000e+00 - val_loss: 16.2622
# Epoch 5/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 7s 944us/step - accuracy: 0.5098 - loss: 0.9939 - val_accuracy: 0.0000e+00 - val_loss: 17.6259
# Epoch 6/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - accuracy: 0.5156 - loss: 0.9824 - val_accuracy: 0.0000e+00 - val_loss: 19.1182
# Epoch 7/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 7s 943us/step - accuracy: 0.5265 - loss: 0.9665 - val_accuracy: 0.0000e+00 - val_loss: 18.8038
# Epoch 8/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 7s 938us/step - accuracy: 0.5298 - loss: 0.9591 - val_accuracy: 2.4038e-04 - val_loss: 18.7970
# Epoch 9/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 7s 963us/step - accuracy: 0.5323 - loss: 0.9534 - val_accuracy: 0.0036 - val_loss: 18.7843
# Epoch 10/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.5358 - loss: 0.9462 - val_accuracy: 9.9588e-04 - val_loss: 19.5396
# Epoch 11/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.5411 - loss: 0.9382 - val_accuracy: 0.0019 - val_loss: 20.3047
# Epoch 12/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.5458 - loss: 0.9294 - val_accuracy: 0.0025 - val_loss: 20.8041
# Epoch 13/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - accuracy: 0.5500 - loss: 0.9214 - val_accuracy: 0.0035 - val_loss: 20.3754
# Epoch 14/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.5555 - loss: 0.9136 - val_accuracy: 0.0051 - val_loss: 20.7976
# Epoch 15/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.5610 - loss: 0.9052 - val_accuracy: 0.0042 - val_loss: 20.2147
# Epoch 16/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.5665 - loss: 0.8954 - val_accuracy: 0.0073 - val_loss: 20.2765
# Epoch 17/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.5717 - loss: 0.8841 - val_accuracy: 0.0073 - val_loss: 20.2892
# Epoch 18/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.5896 - loss: 0.8586 - val_accuracy: 0.0101 - val_loss: 20.6482
# Epoch 19/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.6020 - loss: 0.8361 - val_accuracy: 0.0147 - val_loss: 19.2018
# Epoch 20/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.6122 - loss: 0.8173 - val_accuracy: 0.0110 - val_loss: 19.0983
# Epoch 21/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.6229 - loss: 0.7975 - val_accuracy: 0.0121 - val_loss: 18.9526
# Epoch 22/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.6341 - loss: 0.7799 - val_accuracy: 0.0106 - val_loss: 19.6425
# Epoch 23/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.6432 - loss: 0.7638 - val_accuracy: 0.0135 - val_loss: 20.1920
# Epoch 24/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.6520 - loss: 0.7484 - val_accuracy: 0.0178 - val_loss: 20.9537
# Epoch 25/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - accuracy: 0.6576 - loss: 0.7368 - val_accuracy: 0.0132 - val_loss: 22.3913
# Epoch 26/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.6626 - loss: 0.7264 - val_accuracy: 0.0154 - val_loss: 22.1220
# Epoch 27/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - accuracy: 0.6668 - loss: 0.7172 - val_accuracy: 0.0157 - val_loss: 22.3677
# Epoch 28/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.6691 - loss: 0.7102 - val_accuracy: 0.0101 - val_loss: 23.6631
# Epoch 29/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step - accuracy: 0.6713 - loss: 0.7050 - val_accuracy: 0.0166 - val_loss: 23.6612
# Epoch 30/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - accuracy: 0.6748 - loss: 0.6985 - val_accuracy: 0.0186 - val_loss: 24.1437
# Epoch 31/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - accuracy: 0.6773 - loss: 0.6935 - val_accuracy: 0.0176 - val_loss: 24.2947
# Epoch 32/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step - accuracy: 0.6811 - loss: 0.6874 - val_accuracy: 0.0128 - val_loss: 24.6970
# Epoch 33/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.6841 - loss: 0.6820 - val_accuracy: 0.0118 - val_loss: 25.2953
# Epoch 34/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 7s 973us/step - accuracy: 0.6877 - loss: 0.6757 - val_accuracy: 0.0133 - val_loss: 25.7861
# Epoch 35/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 7s 950us/step - accuracy: 0.6907 - loss: 0.6696 - val_accuracy: 0.0155 - val_loss: 26.8294
# Epoch 36/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - accuracy: 0.6944 - loss: 0.6635 - val_accuracy: 0.0189 - val_loss: 26.8722
# Epoch 37/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.6987 - loss: 0.6567 - val_accuracy: 0.0082 - val_loss: 27.6544
# Epoch 38/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.7026 - loss: 0.6498 - val_accuracy: 0.0104 - val_loss: 27.8198
# Epoch 39/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.7058 - loss: 0.6439 - val_accuracy: 0.0054 - val_loss: 28.0516
# Epoch 40/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.7094 - loss: 0.6382 - val_accuracy: 0.0130 - val_loss: 29.1483
# Epoch 41/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.7129 - loss: 0.6329 - val_accuracy: 0.0163 - val_loss: 28.8990
# Epoch 42/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.7161 - loss: 0.6250 - val_accuracy: 0.0148 - val_loss: 29.7080
# Epoch 43/50
# 7280/7280 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - accuracy: 0.7203 - loss: 0.6179
