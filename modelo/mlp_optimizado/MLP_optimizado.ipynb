# %% [markdown]
# Utilizando los hiperparametros definidos en el siguiente paper:
# [1]
# W. Cambronero, “Poker Hand Dataset: A Machine Learning Analysis and a Practical Linear Transformation.” Accessed: Apr. 22, 2026. [Online]. Available: https://walintonc.github.io/papers/ml_pokerhand.pdf
#
# ‌

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, f1_score
import seaborn as sns
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras.optimizers import Adam as adam
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Se lee el dataset preprocesado
df = pd.read_csv('../../preprocesamiento/preprocesamiento_trainning.data', header=None)
df_val = pd.read_csv('../../preprocesamiento/preprocesamiento_validation.data', header=None)


x = df.iloc[:, :-1].values
y = df.iloc[:, -1].values
x_val = df_val.iloc[:, :-1].values
y_val = df_val.iloc[:, -1].values

clases = sorted(np.unique(y).astype(int).tolist())
clase_nombres = {
    0: "High Card", 1: "One Pair", 2: "Two Pairs", 3: "Three of a Kind",
    4: "Straight",  5: "Flush",   6: "Full House", 7: "Four of a Kind",
    8: "Straight Flush", 9: "Royal Flush"
}
nombres_ordenados = [clase_nombres[c] for c in clases]

# Número de clases distintas
# Número de características (features) por muestra
n_clases = len(np.unique(y))
n_features = x.shape[1]


modelo_tf = keras.Sequential([    
    # Capa de entrada: recibe vectores de tamaño n_features
    keras.layers.Input(shape=(n_features,)),
    # Primera capa oculta con 100 neuronas y activación ReLU
    keras.layers.Dense(100, activation='relu', kernel_regularizer=keras.regularizers.l2(0.0001)),
    # Segunda capa oculta con 10 neuronas y activación ReLU
    keras.layers.Dense(100, activation='relu', kernel_regularizer=keras.regularizers.l2(0.0001)),
    # Tercera capa oculta con 100 neuronas y activación ReLU
    keras.layers.Dense(100, activation='relu', kernel_regularizer=keras.regularizers.l2(0.0001)),
    # Capa de salida:
    # n_clases neuronas (una por clase)
    # softmax convierte las salidas en probabilidades
    keras.layers.Dense(n_clases, activation='softmax')
])


# Compilación del modelo:
modelo_tf.compile(
    optimizer=adam(learning_rate=0.01),  
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Muestra un resumen del modelo (capas, parámetros, etc.)
modelo_tf.summary()

history = modelo_tf.fit(
    x, y,
    epochs=200,
    batch_size=200,
    validation_data=(x_val, y_val), 
    verbose=1
)

EarlyStopping(patience=10, restore_best_weights=True)

# Predicciones del modelo (probabilidades por clase)
y_pred_tf = np.argmax(modelo_tf.predict(x), axis=1)

# Se usa argmax para convertir probabilidades en la clase con mayor valor

# Accuracy: proporción de aciertosprint(f"Accuracy : {accuracy_score(y, y_pred_tf):.4f}")# Recall macro: promedio del recall por clase (útil en datasets desbalanceados)print(f"Recall   : {recall_score(y, y_pred_tf, average='macro', zero_division=0):.4f}")# F1-score macro: balance entre precisión y recall por clase
print(f"Accuracy : {accuracy_score(y, y_pred_tf):.4f}")
print(f"Recall   : {recall_score(y, y_pred_tf, average='macro'):.4f}")
print(f"F1       : {f1_score(y, y_pred_tf, average='macro', zero_division=0):.4f}")

y_pred_val = np.argmax(modelo_tf.predict(x_val), axis=1)

print(f"Accuracy (val): {accuracy_score(y_val, y_pred_val):.4f}")
print(f"Recall   (val): {recall_score(y_val, y_pred_val, average='macro'):.4f}")
print(f"F1       (val): {f1_score(y_val, y_pred_val, average='macro'):.4f}")

# Calcula la matriz de confusión
cm_tf = confusion_matrix(y, y_pred_tf)
modelo_tf.evaluate(x_val, y_val)

# Se grafica con seaborn
plt.figure(figsize=(10, 7))
sns.heatmap(
    cm_tf, 
    annot=True,        # muestra números dentro de cada celda
    fmt='d',           # formato entero
    cmap='Blues',      # esquema de colores
    xticklabels=nombres_ordenados,
    yticklabels=nombres_ordenados,
)

# Etiquetas del gráfico
plt.title("Matriz de Confusión — MLP TensorFlow")
plt.xlabel("Predicho")
plt.ylabel("Real")

# Ajustes visuales
plt.tick_params(axis='x', rotation=45)
plt.tick_params(axis='y', rotation=0)
plt.tight_layout()

# Mostrar gráfico
plt.show()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_8 (Dense)                 │ (None, 100)            │         2,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 100)            │        10,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 100)            │        10,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 10)             │         1,010 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,810 (93.01 KB)
#  Trainable params: 23,810 (93.01 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.2631 - loss: 1.6474 - val_accuracy: 0.3207 - val_loss: 1.4213
# Epoch 2/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3145 - loss: 1.5454 - val_accuracy: 0.3268 - val_loss: 1.4570
# Epoch 3/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3354 - loss: 1.4889 - val_accuracy: 0.3829 - val_loss: 1.4148
# Epoch 4/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3562 - loss: 1.4397 - val_accuracy: 0.3477 - val_loss: 1.4188
# Epoch 5/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3649 - loss: 1.4129 - val_accuracy: 0.4324 - val_loss: 1.3151
# Epoch 6/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3784 - loss: 1.3935 - val_accuracy: 0.4015 - val_loss: 1.3382
# Epoch 7/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3865 - loss: 1.3752 - val_accuracy: 0.4240 - val_loss: 1.3239
# Epoch 8/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3959 - loss: 1.3610 - val_accuracy: 0.4179 - val_loss: 1.2984
# Epoch 9/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4105 - loss: 1.3417 - val_accuracy: 0.4389 - val_loss: 1.2423
# Epoch 10/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4211 - loss: 1.3195 - val_accuracy: 0.4260 - val_loss: 1.2542
# Epoch 11/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4316 - loss: 1.3065 - val_accuracy: 0.4486 - val_loss: 1.2517
# Epoch 12/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4435 - loss: 1.2908 - val_accuracy: 0.4314 - val_loss: 1.2247
# Epoch 13/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4518 - loss: 1.2758 - val_accuracy: 0.3846 - val_loss: 1.3336
# Epoch 14/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4541 - loss: 1.2676 - val_accuracy: 0.4539 - val_loss: 1.2202
# Epoch 15/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4617 - loss: 1.2582 - val_accuracy: 0.4602 - val_loss: 1.1984
# Epoch 16/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4661 - loss: 1.2483 - val_accuracy: 0.4651 - val_loss: 1.1997
# Epoch 17/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4736 - loss: 1.2362 - val_accuracy: 0.4341 - val_loss: 1.2450
# Epoch 18/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4808 - loss: 1.2214 - val_accuracy: 0.4339 - val_loss: 1.2443
# Epoch 19/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4837 - loss: 1.2108 - val_accuracy: 0.4854 - val_loss: 1.1487
# Epoch 20/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4908 - loss: 1.2035 - val_accuracy: 0.4262 - val_loss: 1.2762
# Epoch 21/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4958 - loss: 1.1917 - val_accuracy: 0.4921 - val_loss: 1.1490
# Epoch 22/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5016 - loss: 1.1764 - val_accuracy: 0.4782 - val_loss: 1.1796
# Epoch 23/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5081 - loss: 1.1670 - val_accuracy: 0.4602 - val_loss: 1.2009
# Epoch 24/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5146 - loss: 1.1537 - val_accuracy: 0.4322 - val_loss: 1.2501
# Epoch 25/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5194 - loss: 1.1414 - val_accuracy: 0.4739 - val_loss: 1.1721
# Epoch 26/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5264 - loss: 1.1290 - val_accuracy: 0.4901 - val_loss: 1.1552
# Epoch 27/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5301 - loss: 1.1270 - val_accuracy: 0.4495 - val_loss: 1.2497
# Epoch 28/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5431 - loss: 1.1053 - val_accuracy: 0.4878 - val_loss: 1.1363
# Epoch 29/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5419 - loss: 1.1040 - val_accuracy: 0.4947 - val_loss: 1.1703
# Epoch 30/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5516 - loss: 1.0873 - val_accuracy: 0.4635 - val_loss: 1.2265
# Epoch 31/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5577 - loss: 1.0793 - val_accuracy: 0.5259 - val_loss: 1.0887
# Epoch 32/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5682 - loss: 1.0609 - val_accuracy: 0.5169 - val_loss: 1.1091
# Epoch 33/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5699 - loss: 1.0549 - val_accuracy: 0.4257 - val_loss: 1.2912
# Epoch 34/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5810 - loss: 1.0363 - val_accuracy: 0.5056 - val_loss: 1.1172
# Epoch 35/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5877 - loss: 1.0184 - val_accuracy: 0.5290 - val_loss: 1.0749
# Epoch 36/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5951 - loss: 1.0030 - val_accuracy: 0.5055 - val_loss: 1.1203
# Epoch 37/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6015 - loss: 0.9885 - val_accuracy: 0.5076 - val_loss: 1.1109
# Epoch 38/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6063 - loss: 0.9774 - val_accuracy: 0.4996 - val_loss: 1.1420
# Epoch 39/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6101 - loss: 0.9657 - val_accuracy: 0.5586 - val_loss: 1.0151
# Epoch 40/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6263 - loss: 0.9376 - val_accuracy: 0.5130 - val_loss: 1.1125
# Epoch 41/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6321 - loss: 0.9168 - val_accuracy: 0.4907 - val_loss: 1.1566
# Epoch 42/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6419 - loss: 0.9014 - val_accuracy: 0.5701 - val_loss: 0.9905
# Epoch 43/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6480 - loss: 0.8913 - val_accuracy: 0.5157 - val_loss: 1.1168
# Epoch 44/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6566 - loss: 0.8711 - val_accuracy: 0.5421 - val_loss: 1.0757
# Epoch 45/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6582 - loss: 0.8722 - val_accuracy: 0.5510 - val_loss: 1.0403
# Epoch 46/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6625 - loss: 0.8619 - val_accuracy: 0.5123 - val_loss: 1.1608
# Epoch 47/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6710 - loss: 0.8407 - val_accuracy: 0.5179 - val_loss: 1.1513
# Epoch 48/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6746 - loss: 0.8404 - val_accuracy: 0.5633 - val_loss: 1.0113
# Epoch 49/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6861 - loss: 0.8160 - val_accuracy: 0.5443 - val_loss: 1.0680
# Epoch 50/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6871 - loss: 0.8132 - val_accuracy: 0.5637 - val_loss: 1.0473
# Epoch 51/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6902 - loss: 0.8080 - val_accuracy: 0.5833 - val_loss: 0.9784
# Epoch 52/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6888 - loss: 0.8071 - val_accuracy: 0.5991 - val_loss: 0.9568
# Epoch 53/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6971 - loss: 0.7898 - val_accuracy: 0.6132 - val_loss: 0.9277
# Epoch 54/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6982 - loss: 0.7883 - val_accuracy: 0.5899 - val_loss: 0.9813
# Epoch 55/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7053 - loss: 0.7748 - val_accuracy: 0.6100 - val_loss: 0.9355
# Epoch 56/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7079 - loss: 0.7716 - val_accuracy: 0.6012 - val_loss: 0.9594
# Epoch 57/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7115 - loss: 0.7646 - val_accuracy: 0.5820 - val_loss: 1.0119
# Epoch 58/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7166 - loss: 0.7541 - val_accuracy: 0.6305 - val_loss: 0.8942
# Epoch 59/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7266 - loss: 0.7327 - val_accuracy: 0.5982 - val_loss: 0.9893
# Epoch 60/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7324 - loss: 0.7207 - val_accuracy: 0.6169 - val_loss: 0.9282
# Epoch 61/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7396 - loss: 0.7081 - val_accuracy: 0.6386 - val_loss: 0.8896
# Epoch 62/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7421 - loss: 0.7026 - val_accuracy: 0.6151 - val_loss: 0.9381
# Epoch 63/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7419 - loss: 0.7006 - val_accuracy: 0.6163 - val_loss: 0.9531
# Epoch 64/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7513 - loss: 0.6789 - val_accuracy: 0.6449 - val_loss: 0.8606
# Epoch 65/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7562 - loss: 0.6752 - val_accuracy: 0.6231 - val_loss: 0.9141
# Epoch 66/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7616 - loss: 0.6528 - val_accuracy: 0.6545 - val_loss: 0.8411
# Epoch 67/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7634 - loss: 0.6592 - val_accuracy: 0.6150 - val_loss: 0.9342
# Epoch 68/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7609 - loss: 0.6644 - val_accuracy: 0.6280 - val_loss: 0.9358
# Epoch 69/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7700 - loss: 0.6417 - val_accuracy: 0.6436 - val_loss: 0.8985
# Epoch 70/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7733 - loss: 0.6353 - val_accuracy: 0.6650 - val_loss: 0.8363
# Epoch 71/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7744 - loss: 0.6253 - val_accuracy: 0.6673 - val_loss: 0.8215
# Epoch 72/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7778 - loss: 0.6239 - val_accuracy: 0.6714 - val_loss: 0.8193
# Epoch 73/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7818 - loss: 0.6135 - val_accuracy: 0.6717 - val_loss: 0.8130
# Epoch 74/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7775 - loss: 0.6240 - val_accuracy: 0.6507 - val_loss: 0.8615
# Epoch 75/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7854 - loss: 0.6126 - val_accuracy: 0.6829 - val_loss: 0.8016
# Epoch 76/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7877 - loss: 0.6065 - val_accuracy: 0.6507 - val_loss: 0.9056
# Epoch 77/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7826 - loss: 0.6257 - val_accuracy: 0.6648 - val_loss: 0.8578
# Epoch 78/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7910 - loss: 0.5999 - val_accuracy: 0.6933 - val_loss: 0.7895
# Epoch 79/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7983 - loss: 0.5841 - val_accuracy: 0.6946 - val_loss: 0.7758
# Epoch 80/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7997 - loss: 0.5854 - val_accuracy: 0.6446 - val_loss: 0.9256
# Epoch 81/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8001 - loss: 0.5874 - val_accuracy: 0.7183 - val_loss: 0.7149
# Epoch 82/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8066 - loss: 0.5656 - val_accuracy: 0.7163 - val_loss: 0.7325
# Epoch 83/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8097 - loss: 0.5664 - val_accuracy: 0.7020 - val_loss: 0.7635
# Epoch 84/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8015 - loss: 0.5806 - val_accuracy: 0.6980 - val_loss: 0.7793
# Epoch 85/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8140 - loss: 0.5551 - val_accuracy: 0.6901 - val_loss: 0.8170
# Epoch 86/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8174 - loss: 0.5470 - val_accuracy: 0.7053 - val_loss: 0.7783
# Epoch 87/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8180 - loss: 0.5430 - val_accuracy: 0.7417 - val_loss: 0.6722
# Epoch 88/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8188 - loss: 0.5440 - val_accuracy: 0.7111 - val_loss: 0.7403
# Epoch 89/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8186 - loss: 0.5421 - val_accuracy: 0.7077 - val_loss: 0.7699
# Epoch 90/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8257 - loss: 0.5287 - val_accuracy: 0.7290 - val_loss: 0.6997
# Epoch 91/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8216 - loss: 0.5373 - val_accuracy: 0.7498 - val_loss: 0.6591
# Epoch 92/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8271 - loss: 0.5283 - val_accuracy: 0.7196 - val_loss: 0.7320
# Epoch 93/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8282 - loss: 0.5290 - val_accuracy: 0.7313 - val_loss: 0.7180
# Epoch 94/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8265 - loss: 0.5276 - val_accuracy: 0.6991 - val_loss: 0.8130
# Epoch 95/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8345 - loss: 0.5111 - val_accuracy: 0.7451 - val_loss: 0.6840
# Epoch 96/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8305 - loss: 0.5218 - val_accuracy: 0.7178 - val_loss: 0.7405
# Epoch 97/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8365 - loss: 0.5088 - val_accuracy: 0.7120 - val_loss: 0.7621
# Epoch 98/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8381 - loss: 0.5015 - val_accuracy: 0.7415 - val_loss: 0.7046
# Epoch 99/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8370 - loss: 0.5060 - val_accuracy: 0.7371 - val_loss: 0.6966
# Epoch 100/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8392 - loss: 0.5013 - val_accuracy: 0.7457 - val_loss: 0.6858
# Epoch 101/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8357 - loss: 0.5122 - val_accuracy: 0.7285 - val_loss: 0.7491
# Epoch 102/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8451 - loss: 0.4936 - val_accuracy: 0.7674 - val_loss: 0.6508
# Epoch 103/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8409 - loss: 0.5031 - val_accuracy: 0.7459 - val_loss: 0.6879
# Epoch 104/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8516 - loss: 0.4790 - val_accuracy: 0.7415 - val_loss: 0.7116
# Epoch 105/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8522 - loss: 0.4747 - val_accuracy: 0.7581 - val_loss: 0.6731
# Epoch 106/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8503 - loss: 0.4806 - val_accuracy: 0.7426 - val_loss: 0.7274
# Epoch 107/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8440 - loss: 0.5013 - val_accuracy: 0.7641 - val_loss: 0.6564
# Epoch 108/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8550 - loss: 0.4719 - val_accuracy: 0.7808 - val_loss: 0.6193
# Epoch 109/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8547 - loss: 0.4714 - val_accuracy: 0.7741 - val_loss: 0.6332
# Epoch 110/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8503 - loss: 0.4867 - val_accuracy: 0.7251 - val_loss: 0.7738
# Epoch 111/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8561 - loss: 0.4720 - val_accuracy: 0.7750 - val_loss: 0.6316
# Epoch 112/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8601 - loss: 0.4584 - val_accuracy: 0.7431 - val_loss: 0.7103
# Epoch 113/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8684 - loss: 0.4410 - val_accuracy: 0.7932 - val_loss: 0.5975
# Epoch 114/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8544 - loss: 0.4698 - val_accuracy: 0.7843 - val_loss: 0.6246
# Epoch 115/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8577 - loss: 0.4637 - val_accuracy: 0.7883 - val_loss: 0.6177
# Epoch 116/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8671 - loss: 0.4507 - val_accuracy: 0.7825 - val_loss: 0.6436
# Epoch 117/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8708 - loss: 0.4411 - val_accuracy: 0.7433 - val_loss: 0.7065
# Epoch 118/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8596 - loss: 0.4631 - val_accuracy: 0.7958 - val_loss: 0.6022
# Epoch 119/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8656 - loss: 0.4577 - val_accuracy: 0.7917 - val_loss: 0.5925
# Epoch 120/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8681 - loss: 0.4479 - val_accuracy: 0.7839 - val_loss: 0.6250
# Epoch 121/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8724 - loss: 0.4404 - val_accuracy: 0.7724 - val_loss: 0.6518
# Epoch 122/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8673 - loss: 0.4607 - val_accuracy: 0.7883 - val_loss: 0.6232
# Epoch 123/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8754 - loss: 0.4336 - val_accuracy: 0.7880 - val_loss: 0.6186
# Epoch 124/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8823 - loss: 0.4165 - val_accuracy: 0.7960 - val_loss: 0.6156
# Epoch 125/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8697 - loss: 0.4553 - val_accuracy: 0.7955 - val_loss: 0.6025
# Epoch 126/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8830 - loss: 0.4149 - val_accuracy: 0.8067 - val_loss: 0.5703
# Epoch 127/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8800 - loss: 0.4287 - val_accuracy: 0.8048 - val_loss: 0.5862
# Epoch 128/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8850 - loss: 0.4097 - val_accuracy: 0.8242 - val_loss: 0.5471
# Epoch 129/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8855 - loss: 0.4137 - val_accuracy: 0.8188 - val_loss: 0.5573
# Epoch 130/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8848 - loss: 0.4161 - val_accuracy: 0.8370 - val_loss: 0.5133
# Epoch 131/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8825 - loss: 0.4178 - val_accuracy: 0.8105 - val_loss: 0.5625
# Epoch 132/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8807 - loss: 0.4284 - val_accuracy: 0.8046 - val_loss: 0.5960
# Epoch 133/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8749 - loss: 0.4434 - val_accuracy: 0.8164 - val_loss: 0.5731
# Epoch 134/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8911 - loss: 0.4026 - val_accuracy: 0.8164 - val_loss: 0.5625
# Epoch 135/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8874 - loss: 0.4106 - val_accuracy: 0.7977 - val_loss: 0.5887
# Epoch 136/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8904 - loss: 0.4017 - val_accuracy: 0.8122 - val_loss: 0.5861
# Epoch 137/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8884 - loss: 0.4071 - val_accuracy: 0.8308 - val_loss: 0.5486
# Epoch 138/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8903 - loss: 0.4060 - val_accuracy: 0.8220 - val_loss: 0.5525
# Epoch 139/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8767 - loss: 0.4444 - val_accuracy: 0.8202 - val_loss: 0.5569
# Epoch 140/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8951 - loss: 0.3962 - val_accuracy: 0.8189 - val_loss: 0.5609
# Epoch 141/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8982 - loss: 0.3866 - val_accuracy: 0.8377 - val_loss: 0.5166
# Epoch 142/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8918 - loss: 0.4018 - val_accuracy: 0.8086 - val_loss: 0.6065
# Epoch 143/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8865 - loss: 0.4165 - val_accuracy: 0.8006 - val_loss: 0.6018
# Epoch 144/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8861 - loss: 0.4162 - val_accuracy: 0.8215 - val_loss: 0.5513
# Epoch 145/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9023 - loss: 0.3750 - val_accuracy: 0.8344 - val_loss: 0.5236
# Epoch 146/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8925 - loss: 0.4002 - val_accuracy: 0.8216 - val_loss: 0.5741
# Epoch 147/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8982 - loss: 0.3865 - val_accuracy: 0.8224 - val_loss: 0.5795
# Epoch 148/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9000 - loss: 0.3771 - val_accuracy: 0.8183 - val_loss: 0.5730
# Epoch 149/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8845 - loss: 0.4262 - val_accuracy: 0.8216 - val_loss: 0.5840
# Epoch 150/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8980 - loss: 0.3876 - val_accuracy: 0.8350 - val_loss: 0.5389
# Epoch 151/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8958 - loss: 0.3924 - val_accuracy: 0.8039 - val_loss: 0.6223
# Epoch 152/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8942 - loss: 0.3938 - val_accuracy: 0.8377 - val_loss: 0.5322
# Epoch 153/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8928 - loss: 0.4022 - val_accuracy: 0.8020 - val_loss: 0.6109
# Epoch 154/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9029 - loss: 0.3715 - val_accuracy: 0.8432 - val_loss: 0.4961
# Epoch 155/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9063 - loss: 0.3667 - val_accuracy: 0.8490 - val_loss: 0.5001
# Epoch 156/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8966 - loss: 0.3949 - val_accuracy: 0.8533 - val_loss: 0.4821
# Epoch 157/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9054 - loss: 0.3695 - val_accuracy: 0.8321 - val_loss: 0.5280
# Epoch 158/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8953 - loss: 0.3993 - val_accuracy: 0.8602 - val_loss: 0.4712
# Epoch 159/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9093 - loss: 0.3595 - val_accuracy: 0.8432 - val_loss: 0.4988
# Epoch 160/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9100 - loss: 0.3619 - val_accuracy: 0.8593 - val_loss: 0.4581
# Epoch 161/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9019 - loss: 0.3838 - val_accuracy: 0.8257 - val_loss: 0.5552
# Epoch 162/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9131 - loss: 0.3532 - val_accuracy: 0.8544 - val_loss: 0.4859
# Epoch 163/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9055 - loss: 0.3706 - val_accuracy: 0.8416 - val_loss: 0.5163
# Epoch 164/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8956 - loss: 0.4007 - val_accuracy: 0.8568 - val_loss: 0.4863
# Epoch 165/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9053 - loss: 0.3761 - val_accuracy: 0.8594 - val_loss: 0.4757
# Epoch 166/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9172 - loss: 0.3402 - val_accuracy: 0.8636 - val_loss: 0.4605
# Epoch 167/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9093 - loss: 0.3623 - val_accuracy: 0.8586 - val_loss: 0.4704
# Epoch 168/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9182 - loss: 0.3359 - val_accuracy: 0.8602 - val_loss: 0.4698
# Epoch 169/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9142 - loss: 0.3474 - val_accuracy: 0.8481 - val_loss: 0.5118
# Epoch 170/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8943 - loss: 0.4051 - val_accuracy: 0.8087 - val_loss: 0.6183
# Epoch 171/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9096 - loss: 0.3640 - val_accuracy: 0.8547 - val_loss: 0.4729
# Epoch 172/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9073 - loss: 0.3702 - val_accuracy: 0.8598 - val_loss: 0.4757
# Epoch 173/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9255 - loss: 0.3216 - val_accuracy: 0.8723 - val_loss: 0.4349
# Epoch 174/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9098 - loss: 0.3636 - val_accuracy: 0.8493 - val_loss: 0.4945
# Epoch 175/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9138 - loss: 0.3518 - val_accuracy: 0.8499 - val_loss: 0.5137
# Epoch 176/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9113 - loss: 0.3550 - val_accuracy: 0.8581 - val_loss: 0.4608
# Epoch 177/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9247 - loss: 0.3179 - val_accuracy: 0.8751 - val_loss: 0.4371
# Epoch 178/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9177 - loss: 0.3420 - val_accuracy: 0.8727 - val_loss: 0.4462
# Epoch 179/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9129 - loss: 0.3549 - val_accuracy: 0.8488 - val_loss: 0.4932
# Epoch 180/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9102 - loss: 0.3664 - val_accuracy: 0.8622 - val_loss: 0.4496
# Epoch 181/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9155 - loss: 0.3499 - val_accuracy: 0.8635 - val_loss: 0.4627
# Epoch 182/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9214 - loss: 0.3295 - val_accuracy: 0.8274 - val_loss: 0.5551
# Epoch 183/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9098 - loss: 0.3661 - val_accuracy: 0.8480 - val_loss: 0.5773
# Epoch 184/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9212 - loss: 0.3342 - val_accuracy: 0.8748 - val_loss: 0.4190
# Epoch 185/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9238 - loss: 0.3208 - val_accuracy: 0.8792 - val_loss: 0.4161
# Epoch 186/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9040 - loss: 0.3864 - val_accuracy: 0.7886 - val_loss: 0.6766
# Epoch 187/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9056 - loss: 0.3815 - val_accuracy: 0.8408 - val_loss: 0.4983
# Epoch 188/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9329 - loss: 0.3029 - val_accuracy: 0.8479 - val_loss: 0.4947
# Epoch 189/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9124 - loss: 0.3537 - val_accuracy: 0.8236 - val_loss: 0.5786
# Epoch 190/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9208 - loss: 0.3330 - val_accuracy: 0.8812 - val_loss: 0.4182
# Epoch 191/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9283 - loss: 0.3159 - val_accuracy: 0.8680 - val_loss: 0.4449
# Epoch 192/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9050 - loss: 0.3827 - val_accuracy: 0.8670 - val_loss: 0.4523
# Epoch 193/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9181 - loss: 0.3429 - val_accuracy: 0.8831 - val_loss: 0.4218
# Epoch 194/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9201 - loss: 0.3400 - val_accuracy: 0.8751 - val_loss: 0.4383
# Epoch 195/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9301 - loss: 0.3058 - val_accuracy: 0.8725 - val_loss: 0.4303
# Epoch 196/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9100 - loss: 0.3657 - val_accuracy: 0.8612 - val_loss: 0.4774
# Epoch 197/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9268 - loss: 0.3218 - val_accuracy: 0.8729 - val_loss: 0.4309
# Epoch 198/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9213 - loss: 0.3344 - val_accuracy: 0.8787 - val_loss: 0.4179
# Epoch 199/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9107 - loss: 0.3691 - val_accuracy: 0.8184 - val_loss: 0.5989
# Epoch 200/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9206 - loss: 0.3400 - val_accuracy: 0.8713 - val_loss: 0.4373
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 1s 577us/step
# Accuracy : 0.9246
# Recall   : 0.9141
# F1       : 0.9189
# 6250/6250 ━━━━━━━━━━━━━━━━━━━━ 4s 580us/step
# Accuracy (val): 0.8713
# Recall   (val): 0.9506
# F1       (val): 0.8756
# 6250/6250 ━━━━━━━━━━━━━━━━━━━━ 5s 714us/step - accuracy: 0.8713 - loss: 0.4373

# %%
import matplotlib.pyplot as plt

# Accuracy
plt.figure(figsize=(10,5))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')

plt.title('Curva de aprendizaje - Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.show()

# %%
modelo_tf.save("modelo_poker_optimizado.keras")
