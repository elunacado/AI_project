# %% [markdown]
# Utilizando los hiperparametros definidos en el siguiente paper:
# [1]
# W. Cambronero, “Poker Hand Dataset: A Machine Learning Analysis and a Practical Linear Transformation.” Accessed: Apr. 22, 2026. [Online]. Available: https://walintonc.github.io/papers/ml_pokerhand.pdf
#
# ‌

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, f1_score
import seaborn as sns
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras.optimizers import Adam as adam
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Se lee el dataset preprocesado
df = pd.read_csv('../../preprocesamiento/preprocesamiento_trainning.data', header=None)
df_val = pd.read_csv('../../preprocesamiento/preprocesamiento_validation.data', header=None)


x = df.iloc[:, :-1].values
y = df.iloc[:, -1].values
x_val = df_val.iloc[:, :-1].values
y_val = df_val.iloc[:, -1].values

clases = sorted(np.unique(y).astype(int).tolist())
clase_nombres = {
    0: "High Card", 1: "One Pair", 2: "Two Pairs", 3: "Three of a Kind",
    4: "Straight",  5: "Flush",   6: "Full House", 7: "Four of a Kind",
    8: "Straight Flush", 9: "Royal Flush"
}
nombres_ordenados = [clase_nombres[c] for c in clases]

# Número de clases distintas
# Número de características (features) por muestra
n_clases = len(np.unique(y))
n_features = x.shape[1]


modelo_tf = keras.Sequential([    
    # Capa de entrada: recibe vectores de tamaño n_features
    keras.layers.Input(shape=(n_features,)),
    # Primera capa oculta con 100 neuronas y activación ReLU
    keras.layers.Dense(100, activation='relu', kernel_regularizer=keras.regularizers.l2(0.0001)),
    # Segunda capa oculta con 10 neuronas y activación ReLU
    keras.layers.Dense(100, activation='relu', kernel_regularizer=keras.regularizers.l2(0.0001)),
    # Tercera capa oculta con 100 neuronas y activación ReLU
    keras.layers.Dense(100, activation='relu', kernel_regularizer=keras.regularizers.l2(0.0001)),
    # Capa de salida:
    # n_clases neuronas (una por clase)
    # softmax convierte las salidas en probabilidades
    keras.layers.Dense(n_clases, activation='softmax')
])


# Compilación del modelo:
modelo_tf.compile(
    optimizer=adam(learning_rate=0.01),  
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Muestra un resumen del modelo (capas, parámetros, etc.)
modelo_tf.summary()

history = modelo_tf.fit(
    x, y,
    epochs=200,
    batch_size=200,
    validation_data=(x_val, y_val), 
    verbose=1
)

EarlyStopping(patience=10, restore_best_weights=True)

# Predicciones del modelo (probabilidades por clase)
y_pred_tf = np.argmax(modelo_tf.predict(x), axis=1)

# Se usa argmax para convertir probabilidades en la clase con mayor valor

# Accuracy: proporción de aciertosprint(f"Accuracy : {accuracy_score(y, y_pred_tf):.4f}")# Recall macro: promedio del recall por clase (útil en datasets desbalanceados)print(f"Recall   : {recall_score(y, y_pred_tf, average='macro', zero_division=0):.4f}")# F1-score macro: balance entre precisión y recall por clase
print(f"Accuracy : {accuracy_score(y, y_pred_tf):.4f}")
print(f"Recall   : {recall_score(y, y_pred_tf, average='macro'):.4f}")
print(f"F1       : {f1_score(y, y_pred_tf, average='macro', zero_division=0):.4f}")

y_pred_val = np.argmax(modelo_tf.predict(x_val), axis=1)

print(f"Accuracy (val): {accuracy_score(y_val, y_pred_val):.4f}")
print(f"Recall   (val): {recall_score(y_val, y_pred_val, average='macro'):.4f}")
print(f"F1       (val): {f1_score(y_val, y_pred_val, average='macro'):.4f}")

# Calcula la matriz de confusión
cm_tf = confusion_matrix(y, y_pred_tf)
modelo_tf.evaluate(x_val, y_val)

# Se grafica con seaborn
plt.figure(figsize=(10, 7))
sns.heatmap(
    cm_tf, 
    annot=True,        # muestra números dentro de cada celda
    fmt='d',           # formato entero
    cmap='Blues',      # esquema de colores
    xticklabels=nombres_ordenados,
    yticklabels=nombres_ordenados,
)

# Etiquetas del gráfico
plt.title("Matriz de Confusión — MLP TensorFlow")
plt.xlabel("Predicho")
plt.ylabel("Real")

# Ajustes visuales
plt.tick_params(axis='x', rotation=45)
plt.tick_params(axis='y', rotation=0)
plt.tight_layout()

# Mostrar gráfico
plt.show()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_20 (Dense)                │ (None, 100)            │         2,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_21 (Dense)                │ (None, 100)            │        10,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_22 (Dense)                │ (None, 100)            │        10,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_23 (Dense)                │ (None, 10)             │         1,010 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,810 (93.01 KB)
#  Trainable params: 23,810 (93.01 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.2681 - loss: 1.6428 - val_accuracy: 0.3381 - val_loss: 1.4374
# Epoch 2/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.3148 - loss: 1.5443 - val_accuracy: 0.3609 - val_loss: 1.4318
# Epoch 3/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.3353 - loss: 1.4894 - val_accuracy: 0.4287 - val_loss: 1.3292
# Epoch 4/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.3528 - loss: 1.4516 - val_accuracy: 0.4098 - val_loss: 1.3475
# Epoch 5/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.3645 - loss: 1.4231 - val_accuracy: 0.4084 - val_loss: 1.3421
# Epoch 6/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.3758 - loss: 1.3981 - val_accuracy: 0.4548 - val_loss: 1.2791
# Epoch 7/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.3911 - loss: 1.3752 - val_accuracy: 0.3695 - val_loss: 1.3717
# Epoch 8/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.3989 - loss: 1.3640 - val_accuracy: 0.4654 - val_loss: 1.2328
# Epoch 9/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.4139 - loss: 1.3383 - val_accuracy: 0.4261 - val_loss: 1.2767
# Epoch 10/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.4270 - loss: 1.3196 - val_accuracy: 0.4276 - val_loss: 1.2887
# Epoch 11/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.4381 - loss: 1.3060 - val_accuracy: 0.4879 - val_loss: 1.1700
# Epoch 12/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4545 - loss: 1.2825 - val_accuracy: 0.4259 - val_loss: 1.2626
# Epoch 13/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4731 - loss: 1.2549 - val_accuracy: 0.4738 - val_loss: 1.1631
# Epoch 14/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4895 - loss: 1.2301 - val_accuracy: 0.4417 - val_loss: 1.2327
# Epoch 15/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5081 - loss: 1.2014 - val_accuracy: 0.4101 - val_loss: 1.3095
# Epoch 16/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5299 - loss: 1.1575 - val_accuracy: 0.4901 - val_loss: 1.1400
# Epoch 17/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5453 - loss: 1.1299 - val_accuracy: 0.5019 - val_loss: 1.1290
# Epoch 18/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5584 - loss: 1.0995 - val_accuracy: 0.4723 - val_loss: 1.1838
# Epoch 19/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5686 - loss: 1.0787 - val_accuracy: 0.5397 - val_loss: 1.0582
# Epoch 20/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5750 - loss: 1.0582 - val_accuracy: 0.4782 - val_loss: 1.1883
# Epoch 21/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5890 - loss: 1.0311 - val_accuracy: 0.4990 - val_loss: 1.1331
# Epoch 22/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5887 - loss: 1.0250 - val_accuracy: 0.5517 - val_loss: 1.0344
# Epoch 23/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.6030 - loss: 0.9988 - val_accuracy: 0.4824 - val_loss: 1.1774
# Epoch 24/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.6084 - loss: 0.9848 - val_accuracy: 0.5019 - val_loss: 1.1272
# Epoch 25/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.6149 - loss: 0.9730 - val_accuracy: 0.5202 - val_loss: 1.0909
# Epoch 26/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.6256 - loss: 0.9485 - val_accuracy: 0.5363 - val_loss: 1.0674
# Epoch 27/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.6411 - loss: 0.9199 - val_accuracy: 0.5541 - val_loss: 1.0250
# Epoch 28/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.6428 - loss: 0.9072 - val_accuracy: 0.5595 - val_loss: 1.0134
# Epoch 29/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.6518 - loss: 0.8926 - val_accuracy: 0.5349 - val_loss: 1.0739
# Epoch 30/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.6580 - loss: 0.8819 - val_accuracy: 0.5554 - val_loss: 1.0242
# Epoch 31/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.6644 - loss: 0.8699 - val_accuracy: 0.5837 - val_loss: 0.9613
# Epoch 32/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.6630 - loss: 0.8619 - val_accuracy: 0.5804 - val_loss: 0.9724
# Epoch 33/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.6724 - loss: 0.8484 - val_accuracy: 0.5899 - val_loss: 0.9711
# Epoch 34/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.6747 - loss: 0.8401 - val_accuracy: 0.5745 - val_loss: 0.9937
# Epoch 35/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.6799 - loss: 0.8331 - val_accuracy: 0.5420 - val_loss: 1.0753
# Epoch 36/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.6829 - loss: 0.8288 - val_accuracy: 0.5335 - val_loss: 1.1034
# Epoch 37/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.6896 - loss: 0.8075 - val_accuracy: 0.6036 - val_loss: 0.9177
# Epoch 38/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.6888 - loss: 0.8079 - val_accuracy: 0.6235 - val_loss: 0.8880
# Epoch 39/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.6935 - loss: 0.8014 - val_accuracy: 0.6082 - val_loss: 0.9234
# Epoch 40/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.6943 - loss: 0.7984 - val_accuracy: 0.5871 - val_loss: 0.9703
# Epoch 41/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.7073 - loss: 0.7661 - val_accuracy: 0.5930 - val_loss: 0.9723
# Epoch 42/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7060 - loss: 0.7759 - val_accuracy: 0.6094 - val_loss: 0.9292
# Epoch 43/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7060 - loss: 0.7700 - val_accuracy: 0.6322 - val_loss: 0.8765
# Epoch 44/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7087 - loss: 0.7656 - val_accuracy: 0.5842 - val_loss: 0.9686
# Epoch 45/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.7113 - loss: 0.7553 - val_accuracy: 0.6039 - val_loss: 0.9487
# Epoch 46/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.7139 - loss: 0.7516 - val_accuracy: 0.6136 - val_loss: 0.9195
# Epoch 47/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7119 - loss: 0.7534 - val_accuracy: 0.6381 - val_loss: 0.8668
# Epoch 48/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.7170 - loss: 0.7490 - val_accuracy: 0.6332 - val_loss: 0.8778
# Epoch 49/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.7206 - loss: 0.7407 - val_accuracy: 0.6429 - val_loss: 0.8529
# Epoch 50/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.7289 - loss: 0.7178 - val_accuracy: 0.6504 - val_loss: 0.8375
# Epoch 51/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.7284 - loss: 0.7217 - val_accuracy: 0.6603 - val_loss: 0.8213
# Epoch 52/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7293 - loss: 0.7209 - val_accuracy: 0.6509 - val_loss: 0.8488
# Epoch 53/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.7255 - loss: 0.7256 - val_accuracy: 0.6084 - val_loss: 0.9423
# Epoch 54/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.7281 - loss: 0.7229 - val_accuracy: 0.6615 - val_loss: 0.8264
# Epoch 55/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7334 - loss: 0.7106 - val_accuracy: 0.6419 - val_loss: 0.8595
# Epoch 56/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.7334 - loss: 0.7057 - val_accuracy: 0.6587 - val_loss: 0.8335
# Epoch 57/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.7376 - loss: 0.7048 - val_accuracy: 0.6486 - val_loss: 0.8458
# Epoch 58/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7352 - loss: 0.7059 - val_accuracy: 0.6498 - val_loss: 0.8486
# Epoch 59/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7350 - loss: 0.7069 - val_accuracy: 0.6532 - val_loss: 0.8391
# Epoch 60/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.7346 - loss: 0.7053 - val_accuracy: 0.6286 - val_loss: 0.8823
# Epoch 61/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.7368 - loss: 0.7046 - val_accuracy: 0.6657 - val_loss: 0.8361
# Epoch 62/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.7394 - loss: 0.6955 - val_accuracy: 0.6541 - val_loss: 0.8558
# Epoch 63/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7430 - loss: 0.6868 - val_accuracy: 0.6447 - val_loss: 0.8649
# Epoch 64/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7406 - loss: 0.6941 - val_accuracy: 0.6408 - val_loss: 0.8749
# Epoch 65/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7456 - loss: 0.6933 - val_accuracy: 0.6448 - val_loss: 0.8695
# Epoch 66/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7468 - loss: 0.6824 - val_accuracy: 0.6522 - val_loss: 0.8505
# Epoch 67/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7521 - loss: 0.6751 - val_accuracy: 0.6546 - val_loss: 0.8577
# Epoch 68/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7492 - loss: 0.6816 - val_accuracy: 0.6615 - val_loss: 0.8234
# Epoch 69/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7528 - loss: 0.6661 - val_accuracy: 0.6649 - val_loss: 0.8321
# Epoch 70/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7551 - loss: 0.6672 - val_accuracy: 0.6641 - val_loss: 0.8371
# Epoch 71/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7564 - loss: 0.6603 - val_accuracy: 0.6672 - val_loss: 0.8368
# Epoch 72/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7581 - loss: 0.6575 - val_accuracy: 0.6767 - val_loss: 0.7980
# Epoch 73/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7566 - loss: 0.6651 - val_accuracy: 0.6649 - val_loss: 0.8198
# Epoch 74/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7559 - loss: 0.6625 - val_accuracy: 0.6762 - val_loss: 0.8063
# Epoch 75/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7578 - loss: 0.6640 - val_accuracy: 0.6461 - val_loss: 0.8823
# Epoch 76/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7626 - loss: 0.6519 - val_accuracy: 0.6452 - val_loss: 0.8720
# Epoch 77/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7648 - loss: 0.6505 - val_accuracy: 0.6768 - val_loss: 0.8059
# Epoch 78/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7490 - loss: 0.6843 - val_accuracy: 0.6802 - val_loss: 0.8003
# Epoch 79/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7679 - loss: 0.6387 - val_accuracy: 0.6669 - val_loss: 0.8564
# Epoch 80/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7637 - loss: 0.6505 - val_accuracy: 0.6601 - val_loss: 0.8587
# Epoch 81/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7662 - loss: 0.6490 - val_accuracy: 0.6508 - val_loss: 0.8811
# Epoch 82/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7687 - loss: 0.6398 - val_accuracy: 0.6364 - val_loss: 0.9282
# Epoch 83/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7705 - loss: 0.6391 - val_accuracy: 0.6829 - val_loss: 0.8088
# Epoch 84/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7664 - loss: 0.6512 - val_accuracy: 0.6502 - val_loss: 0.8696
# Epoch 85/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7684 - loss: 0.6404 - val_accuracy: 0.6791 - val_loss: 0.8135
# Epoch 86/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7704 - loss: 0.6411 - val_accuracy: 0.6844 - val_loss: 0.7929
# Epoch 87/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7760 - loss: 0.6296 - val_accuracy: 0.6779 - val_loss: 0.8246
# Epoch 88/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7710 - loss: 0.6423 - val_accuracy: 0.6842 - val_loss: 0.8039
# Epoch 89/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7821 - loss: 0.6170 - val_accuracy: 0.6892 - val_loss: 0.7895
# Epoch 90/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7801 - loss: 0.6192 - val_accuracy: 0.7011 - val_loss: 0.7780
# Epoch 91/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7866 - loss: 0.6065 - val_accuracy: 0.6907 - val_loss: 0.8172
# Epoch 92/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7859 - loss: 0.6074 - val_accuracy: 0.6511 - val_loss: 0.8849
# Epoch 93/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7869 - loss: 0.6104 - val_accuracy: 0.6954 - val_loss: 0.7825
# Epoch 94/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7881 - loss: 0.6064 - val_accuracy: 0.7166 - val_loss: 0.7340
# Epoch 95/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.7969 - loss: 0.5890 - val_accuracy: 0.6864 - val_loss: 0.8110
# Epoch 96/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.7906 - loss: 0.6080 - val_accuracy: 0.7002 - val_loss: 0.7652
# Epoch 97/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.7977 - loss: 0.5897 - val_accuracy: 0.6912 - val_loss: 0.8189
# Epoch 98/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7985 - loss: 0.5892 - val_accuracy: 0.7094 - val_loss: 0.7660
# Epoch 99/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.7978 - loss: 0.5939 - val_accuracy: 0.7022 - val_loss: 0.7873
# Epoch 100/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8040 - loss: 0.5763 - val_accuracy: 0.7247 - val_loss: 0.7318
# Epoch 101/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8031 - loss: 0.5827 - val_accuracy: 0.7258 - val_loss: 0.7262
# Epoch 102/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8053 - loss: 0.5793 - val_accuracy: 0.7422 - val_loss: 0.6916
# Epoch 103/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8118 - loss: 0.5684 - val_accuracy: 0.6970 - val_loss: 0.8170
# Epoch 104/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.8155 - loss: 0.5548 - val_accuracy: 0.7369 - val_loss: 0.7209
# Epoch 105/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8172 - loss: 0.5561 - val_accuracy: 0.7132 - val_loss: 0.7682
# Epoch 106/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.8172 - loss: 0.5594 - val_accuracy: 0.7270 - val_loss: 0.7449
# Epoch 107/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8200 - loss: 0.5520 - val_accuracy: 0.7399 - val_loss: 0.7190
# Epoch 108/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8216 - loss: 0.5496 - val_accuracy: 0.7388 - val_loss: 0.7123
# Epoch 109/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8217 - loss: 0.5477 - val_accuracy: 0.7161 - val_loss: 0.7713
# Epoch 110/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8205 - loss: 0.5500 - val_accuracy: 0.7427 - val_loss: 0.7099
# Epoch 111/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8308 - loss: 0.5312 - val_accuracy: 0.7476 - val_loss: 0.6958
# Epoch 112/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8294 - loss: 0.5318 - val_accuracy: 0.7447 - val_loss: 0.7160
# Epoch 113/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8240 - loss: 0.5474 - val_accuracy: 0.7350 - val_loss: 0.7339
# Epoch 114/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8300 - loss: 0.5321 - val_accuracy: 0.7623 - val_loss: 0.6748
# Epoch 115/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8295 - loss: 0.5389 - val_accuracy: 0.7749 - val_loss: 0.6426
# Epoch 116/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8448 - loss: 0.4999 - val_accuracy: 0.7639 - val_loss: 0.6680
# Epoch 117/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8319 - loss: 0.5306 - val_accuracy: 0.7222 - val_loss: 0.7705
# Epoch 118/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8458 - loss: 0.5006 - val_accuracy: 0.7366 - val_loss: 0.7316
# Epoch 119/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8432 - loss: 0.5087 - val_accuracy: 0.7391 - val_loss: 0.7476
# Epoch 120/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8432 - loss: 0.5049 - val_accuracy: 0.7420 - val_loss: 0.7360
# Epoch 121/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8423 - loss: 0.5085 - val_accuracy: 0.7751 - val_loss: 0.6471
# Epoch 122/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8503 - loss: 0.4897 - val_accuracy: 0.7316 - val_loss: 0.7677
# Epoch 123/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8516 - loss: 0.4857 - val_accuracy: 0.7649 - val_loss: 0.6635
# Epoch 124/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8495 - loss: 0.4918 - val_accuracy: 0.7818 - val_loss: 0.6302
# Epoch 125/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8481 - loss: 0.4909 - val_accuracy: 0.7702 - val_loss: 0.6684
# Epoch 126/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8569 - loss: 0.4715 - val_accuracy: 0.7729 - val_loss: 0.6544
# Epoch 127/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8554 - loss: 0.4739 - val_accuracy: 0.7667 - val_loss: 0.6703
# Epoch 128/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8493 - loss: 0.4877 - val_accuracy: 0.7659 - val_loss: 0.6772
# Epoch 129/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8569 - loss: 0.4759 - val_accuracy: 0.7744 - val_loss: 0.6559
# Epoch 130/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8539 - loss: 0.4815 - val_accuracy: 0.7607 - val_loss: 0.6792
# Epoch 131/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8582 - loss: 0.4692 - val_accuracy: 0.7631 - val_loss: 0.6823
# Epoch 132/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8566 - loss: 0.4773 - val_accuracy: 0.7540 - val_loss: 0.6957
# Epoch 133/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8615 - loss: 0.4640 - val_accuracy: 0.7650 - val_loss: 0.6778
# Epoch 134/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8619 - loss: 0.4625 - val_accuracy: 0.7717 - val_loss: 0.6623
# Epoch 135/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8622 - loss: 0.4628 - val_accuracy: 0.7543 - val_loss: 0.7120
# Epoch 136/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8578 - loss: 0.4737 - val_accuracy: 0.7923 - val_loss: 0.6147
# Epoch 137/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8682 - loss: 0.4470 - val_accuracy: 0.8007 - val_loss: 0.5974
# Epoch 138/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8604 - loss: 0.4669 - val_accuracy: 0.7636 - val_loss: 0.7104
# Epoch 139/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8575 - loss: 0.4789 - val_accuracy: 0.8151 - val_loss: 0.5650
# Epoch 140/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8724 - loss: 0.4371 - val_accuracy: 0.7987 - val_loss: 0.5996
# Epoch 141/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8649 - loss: 0.4597 - val_accuracy: 0.7876 - val_loss: 0.6330
# Epoch 142/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8646 - loss: 0.4639 - val_accuracy: 0.7557 - val_loss: 0.6925
# Epoch 143/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8724 - loss: 0.4442 - val_accuracy: 0.8076 - val_loss: 0.5727
# Epoch 144/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8675 - loss: 0.4529 - val_accuracy: 0.7648 - val_loss: 0.6786
# Epoch 145/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8690 - loss: 0.4512 - val_accuracy: 0.7908 - val_loss: 0.6383
# Epoch 146/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8697 - loss: 0.4533 - val_accuracy: 0.7438 - val_loss: 0.7524
# Epoch 147/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8770 - loss: 0.4341 - val_accuracy: 0.7986 - val_loss: 0.6341
# Epoch 148/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8722 - loss: 0.4477 - val_accuracy: 0.7504 - val_loss: 0.7327
# Epoch 149/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8709 - loss: 0.4460 - val_accuracy: 0.8205 - val_loss: 0.5633
# Epoch 150/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8690 - loss: 0.4510 - val_accuracy: 0.7918 - val_loss: 0.6177
# Epoch 151/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8821 - loss: 0.4214 - val_accuracy: 0.7327 - val_loss: 0.7587
# Epoch 152/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8725 - loss: 0.4469 - val_accuracy: 0.7947 - val_loss: 0.6114
# Epoch 153/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8862 - loss: 0.4145 - val_accuracy: 0.8109 - val_loss: 0.5754
# Epoch 154/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8684 - loss: 0.4561 - val_accuracy: 0.8155 - val_loss: 0.5725
# Epoch 155/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8750 - loss: 0.4460 - val_accuracy: 0.8070 - val_loss: 0.5924
# Epoch 156/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8813 - loss: 0.4286 - val_accuracy: 0.7987 - val_loss: 0.6210
# Epoch 157/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8774 - loss: 0.4371 - val_accuracy: 0.7998 - val_loss: 0.6202
# Epoch 158/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8771 - loss: 0.4390 - val_accuracy: 0.8157 - val_loss: 0.5710
# Epoch 159/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8821 - loss: 0.4238 - val_accuracy: 0.8308 - val_loss: 0.5315
# Epoch 160/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8796 - loss: 0.4296 - val_accuracy: 0.8288 - val_loss: 0.5386
# Epoch 161/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8744 - loss: 0.4454 - val_accuracy: 0.8226 - val_loss: 0.5678
# Epoch 162/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8838 - loss: 0.4181 - val_accuracy: 0.8313 - val_loss: 0.5450
# Epoch 163/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8831 - loss: 0.4228 - val_accuracy: 0.7854 - val_loss: 0.6543
# Epoch 164/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8845 - loss: 0.4184 - val_accuracy: 0.8063 - val_loss: 0.6191
# Epoch 165/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8870 - loss: 0.4162 - val_accuracy: 0.8376 - val_loss: 0.5255
# Epoch 166/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8886 - loss: 0.4109 - val_accuracy: 0.8378 - val_loss: 0.5230
# Epoch 167/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8815 - loss: 0.4277 - val_accuracy: 0.7952 - val_loss: 0.6045
# Epoch 168/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8868 - loss: 0.4187 - val_accuracy: 0.8227 - val_loss: 0.5574
# Epoch 169/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8856 - loss: 0.4133 - val_accuracy: 0.8106 - val_loss: 0.6017
# Epoch 170/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8789 - loss: 0.4385 - val_accuracy: 0.8390 - val_loss: 0.5124
# Epoch 171/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8889 - loss: 0.4090 - val_accuracy: 0.8381 - val_loss: 0.5327
# Epoch 172/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8864 - loss: 0.4142 - val_accuracy: 0.8258 - val_loss: 0.5383
# Epoch 173/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8887 - loss: 0.4129 - val_accuracy: 0.8017 - val_loss: 0.6147
# Epoch 174/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8905 - loss: 0.4022 - val_accuracy: 0.8247 - val_loss: 0.5570
# Epoch 175/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8886 - loss: 0.4123 - val_accuracy: 0.8183 - val_loss: 0.5761
# Epoch 176/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8942 - loss: 0.3964 - val_accuracy: 0.8308 - val_loss: 0.5356
# Epoch 177/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8926 - loss: 0.4031 - val_accuracy: 0.8214 - val_loss: 0.5754
# Epoch 178/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8953 - loss: 0.3956 - val_accuracy: 0.8275 - val_loss: 0.5415
# Epoch 179/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8826 - loss: 0.4263 - val_accuracy: 0.8487 - val_loss: 0.4996
# Epoch 180/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8949 - loss: 0.3964 - val_accuracy: 0.8401 - val_loss: 0.5296
# Epoch 181/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8934 - loss: 0.4016 - val_accuracy: 0.8266 - val_loss: 0.5517
# Epoch 182/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8955 - loss: 0.3943 - val_accuracy: 0.8363 - val_loss: 0.5290
# Epoch 183/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8910 - loss: 0.4072 - val_accuracy: 0.8455 - val_loss: 0.5035
# Epoch 184/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8973 - loss: 0.3892 - val_accuracy: 0.8366 - val_loss: 0.5377
# Epoch 185/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9017 - loss: 0.3793 - val_accuracy: 0.8425 - val_loss: 0.5075
# Epoch 186/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8961 - loss: 0.3889 - val_accuracy: 0.8430 - val_loss: 0.5005
# Epoch 187/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8991 - loss: 0.3837 - val_accuracy: 0.8240 - val_loss: 0.5610
# Epoch 188/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8952 - loss: 0.3956 - val_accuracy: 0.8270 - val_loss: 0.5502
# Epoch 189/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8934 - loss: 0.4012 - val_accuracy: 0.8386 - val_loss: 0.5250
# Epoch 190/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9003 - loss: 0.3824 - val_accuracy: 0.8149 - val_loss: 0.5650
# Epoch 191/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8928 - loss: 0.4009 - val_accuracy: 0.8504 - val_loss: 0.5006
# Epoch 192/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8995 - loss: 0.3885 - val_accuracy: 0.8304 - val_loss: 0.5427
# Epoch 193/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9034 - loss: 0.3808 - val_accuracy: 0.8191 - val_loss: 0.5687
# Epoch 194/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8802 - loss: 0.4409 - val_accuracy: 0.8605 - val_loss: 0.4804
# Epoch 195/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9057 - loss: 0.3748 - val_accuracy: 0.8533 - val_loss: 0.4848
# Epoch 196/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8987 - loss: 0.3901 - val_accuracy: 0.8105 - val_loss: 0.5993
# Epoch 197/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9013 - loss: 0.3757 - val_accuracy: 0.8317 - val_loss: 0.5533
# Epoch 198/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8981 - loss: 0.3909 - val_accuracy: 0.8314 - val_loss: 0.5331
# Epoch 199/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9017 - loss: 0.3857 - val_accuracy: 0.8601 - val_loss: 0.4644
# Epoch 200/200
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9009 - loss: 0.3821 - val_accuracy: 0.8308 - val_loss: 0.5369
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 1s 591us/step
# Accuracy : 0.9012
# Recall   : 0.9476
# F1       : 0.9047
# 6250/6250 ━━━━━━━━━━━━━━━━━━━━ 4s 594us/step
# Accuracy (val): 0.8308
# Recall   (val): 0.8452
# F1       (val): 0.7156
#   68/6250 ━━━━━━━━━━━━━━━━━━━━ 4s 754us/step - accuracy: 0.8489 - loss: 0.4980
# /home/tulocalhost/Downloads/AIProject/venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# 6250/6250 ━━━━━━━━━━━━━━━━━━━━ 5s 723us/step - accuracy: 0.8308 - loss: 0.5369

# %%
import matplotlib.pyplot as plt

# Accuracy
plt.figure(figsize=(10,5))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')

plt.title('Curva de aprendizaje - Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.show()

# %%
modelo_tf.save("modelo_poker_optimizado.keras")
